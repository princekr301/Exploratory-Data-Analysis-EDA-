# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('C:/Users/USER/Downloads/archive (5)/oyorooms.csv')

# %%
df
# Out:
#      Unnamed: 0                                    HOTEL NAME  \
# 0             0                  OYO Premium 529 Jasola Vihar
# 1             1           OYO Flagship 485 GK2 Savitri Cinema
# 2             2               OYO Flagship 573 Paharganj NDLS
# 3             3                OYO Flagship 513 Delhi Airport
# 4             4  OYO Premium 055 New Friends Colony Ring Road
# ..          ...                                           ...
# 326         326             OYO Premium 346 Connaught Place 2
# 327         327            OYO Rooms 167 Safdarjung Extension
# 328         328      OYO Rooms 222 Karol Bagh Metro Station 3
# 329         329               OYO Rooms 398 South Extension 2
# 330         330          OYO Rooms 516 Shakti Vihar Pitampura
#
#                          LOCALITY REGION OLD PRICE PRICE AFTER DISCOUNT  \
# 0                Pocket-2, Jasola  Delhi    ₹ 2649               ₹ 1987
# 1                     E Block,GK2  Delhi    ₹ 3149               ₹ 2362
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 331 entries, 0 to 330
# Data columns (total 8 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Unnamed: 0            331 non-null    int64
#  1   HOTEL NAME            331 non-null    object
#  2   LOCALITY              331 non-null    object
#  3   REGION                331 non-null    object
#  4   OLD PRICE             330 non-null    object
#  5   PRICE AFTER DISCOUNT  331 non-null    object
#  6   % DISCOUNT            330 non-null    object
#  7   STATUS                331 non-null    object
# dtypes: int64(1), object(7)
# memory usage: 20.8+ KB

# %%
df.isnull().sum()
# Out:
# Unnamed: 0              0
# HOTEL NAME              0
# LOCALITY                0
# REGION                  0
# OLD PRICE               1
# PRICE AFTER DISCOUNT    0
# % DISCOUNT              1
# STATUS                  0
# dtype: int64

# %%
df.drop(columns=['Unnamed: 0'],inplace=True)

# %%
df
# Out:
#                                        HOTEL NAME  \
# 0                    OYO Premium 529 Jasola Vihar
# 1             OYO Flagship 485 GK2 Savitri Cinema
# 2                 OYO Flagship 573 Paharganj NDLS
# 3                  OYO Flagship 513 Delhi Airport
# 4    OYO Premium 055 New Friends Colony Ring Road
# ..                                            ...
# 326             OYO Premium 346 Connaught Place 2
# 327            OYO Rooms 167 Safdarjung Extension
# 328      OYO Rooms 222 Karol Bagh Metro Station 3
# 329               OYO Rooms 398 South Extension 2
# 330          OYO Rooms 516 Shakti Vihar Pitampura
#
#                          LOCALITY REGION OLD PRICE PRICE AFTER DISCOUNT  \
# 0                Pocket-2, Jasola  Delhi    ₹ 2649               ₹ 1987
# 1                     E Block,GK2  Delhi    ₹ 3149               ₹ 2362
# 2       Arakashan Road, Paharganj  Delhi    ₹ 1799               ₹ 1349
# ...

# %%
df['LOCALITY'].unique()
# Out:
# array(['Pocket-2, Jasola', 'E Block,GK2', 'Arakashan Road, Paharganj',
#        'A Block,Mahipalpur Extension', 'CV Raman Marg',
#        'E Block, East Of Kailash', 'Sunder Nagar', 'Kalkaji',
#        'Road 1, Mahipalpur', 'East Patel Nagar', 'Karol Bagh, New Delhi',
#        'Road No 1, Mahipalpur',
#        'Second Floor (With Elevator), New Friends Colony ', 'Saket',
#        'National Highway No. 8, Mahipalpur', 'Connaught Circus',
#        'National Highway 8, Near IGI Domestic Airport, Mahipalpur',
#        'Mahipalpur Extn, Near Airport, National Highway -8', 'Anand Lok',
#        'Vasant vihar', 'Adarsh Nagar',
#        'N.H. 8, Near IGI Airport Road No. 1, Mahipalpur Extension , Mahipalpur',
#        'Greater Kailash 1', 'Kingsaway', 'Jasola Vihar', 'Lajpat Nagar 4',
#        'Outer Ring Road', 'Opposite Karnataka Bank, Kalkaji', 'Dwarka',
#        'Desh Bandhu Gupta Road', 'Bhera Enclave', 'Kirti Nagar',
#        'Near Bank of Baroda', 'Jamia Nagar, Okhla',
# ...

# %%
df['LOCALITY'].value_counts()
# Out:
# Karol Bagh                                             26
# Paharganj                                              11
# Dwarka                                                  8
# Greater Kailash 1                                       6
# East Patel Nagar                                        6
#                                                        ..
# Opposite J Block Market, Saket                          1
# Khasara No.395, Vasant Kunj Road, Mahipalpur            1
# Opposite Kapashera Police Station Kapashera             1
# Greater Kailash Part 1                                  1
# Near Prem Motor Showroom, Adjoining Vasantkunj Road     1
# Name: LOCALITY, Length: 232, dtype: int64

# %% [markdown]
# ## Karol Bagh has the maximum numbers of oyo hotel

# %%
df['OLD PRICE']=df['OLD PRICE'].str.replace('₹','')

# %%
df['PRICE AFTER DISCOUNT']=df['PRICE AFTER DISCOUNT'].str.replace('₹','')

# %%
df['OLD PRICE'].mode()
# Out:
# 0     2049
# dtype: object

# %%
df['PRICE AFTER DISCOUNT']=df['PRICE AFTER DISCOUNT'].astype(int)

# %%
df
# Out:
#                                        HOTEL NAME  \
# 0                    OYO Premium 529 Jasola Vihar
# 1             OYO Flagship 485 GK2 Savitri Cinema
# 2                 OYO Flagship 573 Paharganj NDLS
# 3                  OYO Flagship 513 Delhi Airport
# 4    OYO Premium 055 New Friends Colony Ring Road
# ..                                            ...
# 326             OYO Premium 346 Connaught Place 2
# 327            OYO Rooms 167 Safdarjung Extension
# 328      OYO Rooms 222 Karol Bagh Metro Station 3
# 329               OYO Rooms 398 South Extension 2
# 330          OYO Rooms 516 Shakti Vihar Pitampura
#
#                          LOCALITY REGION OLD PRICE  PRICE AFTER DISCOUNT  \
# 0                Pocket-2, Jasola  Delhi      2649                  1987
# 1                     E Block,GK2  Delhi      3149                  2362
# 2       Arakashan Road, Paharganj  Delhi      1799                  1349
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 331 entries, 0 to 330
# Data columns (total 7 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   HOTEL NAME            331 non-null    object
#  1   LOCALITY              331 non-null    object
#  2   REGION                331 non-null    object
#  3   OLD PRICE             330 non-null    object
#  4   PRICE AFTER DISCOUNT  331 non-null    int32
#  5   % DISCOUNT            330 non-null    object
#  6   STATUS                331 non-null    object
# dtypes: int32(1), object(6)
# memory usage: 16.9+ KB

# %%
df['% DISCOUNT'].unique()
# Out:
# array(['25% OFF', nan], dtype=object)

# %%
df.groupby(['HOTEL NAME','LOCALITY'])['PRICE AFTER DISCOUNT'].agg(['max','min'])
df.sort_values(by='PRICE AFTER DISCOUNT')
# Out:
#                                             HOTEL NAME  \
# 246         OYO Rooms 298 38 Arakashan Road Pahar Ganj
# 318   OYO Rooms 523 Karol Bagh WEA Saraswati Marg 4/39
# 253             OYO Rooms 379 New Delhi Station Gate 1
# 265       OYO Rooms 312 Near New Delhi Railway Station
# 212       OYO Rooms 342 Near RK Ashram Metro Station 4
# ..                                                 ...
# 192  OYO Premium 559 Connaught Place Travellers Del...
# 110           OYO Premium 526 Wazirpur Industrial Area
# 6                           OYO Premium 210 Lodhi Road
# 225                    OYO Premium 140 Connaught Place
# 130                OYO Premium 208 GK 1 M Block Market
#
#                                           LOCALITY REGION OLD PRICE  \
# 246                                  Arakshan Road  Delhi       749
# 318                     Saraswati Marg, Karol Bagh  Delhi      1049
# 253  Opposite New Delhi Railway Station, Paharganj  Delhi      1099
# ...

# %%
df[df.isna().any(axis=1)]
# Out:
#                            HOTEL NAME         LOCALITY REGION OLD PRICE  \
# 323  OYO Premium 335 Model Town Delhi  Bhama Shah Marg  Delhi       NaN
#
#      PRICE AFTER DISCOUNT % DISCOUNT     STATUS
# 323                  3549        NaN  SOLD OUT

# %%
df=df.dropna(axis=0)

# %%
df
# Out:
#                                        HOTEL NAME  \
# 0                    OYO Premium 529 Jasola Vihar
# 1             OYO Flagship 485 GK2 Savitri Cinema
# 2                 OYO Flagship 573 Paharganj NDLS
# 3                  OYO Flagship 513 Delhi Airport
# 4    OYO Premium 055 New Friends Colony Ring Road
# ..                                            ...
# 326             OYO Premium 346 Connaught Place 2
# 327            OYO Rooms 167 Safdarjung Extension
# 328      OYO Rooms 222 Karol Bagh Metro Station 3
# 329               OYO Rooms 398 South Extension 2
# 330          OYO Rooms 516 Shakti Vihar Pitampura
#
#                          LOCALITY REGION OLD PRICE  PRICE AFTER DISCOUNT  \
# 0                Pocket-2, Jasola  Delhi      2649                  1987
# 1                     E Block,GK2  Delhi      3149                  2362
# 2       Arakashan Road, Paharganj  Delhi      1799                  1349
# ...

# %%
df['OLD PRICE']=df['OLD PRICE'].astype(int)
# Out:
# <ipython-input-21-6358c1149ab5>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['OLD PRICE']=df['OLD PRICE'].astype(int)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 330 entries, 0 to 330
# Data columns (total 7 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   HOTEL NAME            330 non-null    object
#  1   LOCALITY              330 non-null    object
#  2   REGION                330 non-null    object
#  3   OLD PRICE             330 non-null    int32
#  4   PRICE AFTER DISCOUNT  330 non-null    int32
#  5   % DISCOUNT            330 non-null    object
#  6   STATUS                330 non-null    object
# dtypes: int32(2), object(5)
# memory usage: 18.0+ KB

# %%
sns.relplot(y=df['OLD PRICE'],x=df['PRICE AFTER DISCOUNT'])

# %%
a=df.groupby(['HOTEL NAME','LOCALITY'])['PRICE AFTER DISCOUNT'].agg(['max','min'])
a
# Out:
#                                                                                           max  \
# HOTEL NAME                               LOCALITY
# OYO Apartments 202 Saket Extension       Near Malkhan Singh Marg, Street no.16            899
# OYO Apartments 273 Dwarka Sector 12      Dwarka                                          1649
# OYO Apartments 561 Ramphal Chowk         Palam Extension, Sector 7, Near Gold's Gym      1424
# OYO Elite 557 Panchsheel Enclave         Panchshila Park                                 4237
# OYO Flagship 485 GK2 Savitri Cinema      E Block,GK2                                     2362
# ...                                                                                       ...
# OYO Rooms 690 Okhla Near Fortis Hospital Jamia Nagar, Okhla                              1874
# OYO Rooms 696 NH8 Mahipalpur             Road 1, Mahipalpur                              1248
# ...

# %%
for i in a:
    print(i)
# Out:
# max
# min

# %%
df.iloc[np.where(df['STATUS']=='Available')]
# Out:
#                                         HOTEL NAME  \
# 0                     OYO Premium 529 Jasola Vihar
# 1              OYO Flagship 485 GK2 Savitri Cinema
# 2                  OYO Flagship 573 Paharganj NDLS
# 3                   OYO Flagship 513 Delhi Airport
# 4     OYO Premium 055 New Friends Colony Ring Road
# ..                                             ...
# 100             OYO Rooms 173 Paharganj Qutub Road
# 101  OYO Rooms 578 Karol Bagh 16/7 Arya Samaj Road
# 102   OYO Rooms 230 Near RK Ashram Metro Paharganj
# 103                    OYO Rooms 626 DB Gupta NDLS
# 104    OYO Rooms 451 Gali No 3 Ram Nagar Paharganj
#
#                                         LOCALITY REGION  OLD PRICE  \
# 0                               Pocket-2, Jasola  Delhi       2649
# 1                                    E Block,GK2  Delhi       3149
# 2                      Arakashan Road, Paharganj  Delhi       1799
# 3                   A Block,Mahipalpur Extension  Delhi       1999
# ...

# %% [markdown]
# ## These are the places u can search for oyo rooms

# %%
df.iloc[np.where(df['STATUS'] == 'SOLD OUT ')]
# Out:
#                                    HOTEL NAME  \
# 105               OYO Flagship 497 Green Park
# 106       OYO Flagship 500 New Friends Colony
# 107          OYO Flagship 494 East of Kailash
# 108       OYO Flagship 512 Safdarjung Enclave
# 109           OYO Flagship 573 Paharganj NDLS
# ..                                        ...
# 326         OYO Premium 346 Connaught Place 2
# 327        OYO Rooms 167 Safdarjung Extension
# 328  OYO Rooms 222 Karol Bagh Metro Station 3
# 329           OYO Rooms 398 South Extension 2
# 330      OYO Rooms 516 Shakti Vihar Pitampura
#
#                                               LOCALITY REGION  OLD PRICE  \
# 105                        B Block, Safdarjung Enclave  Delhi       5049
# 106  Plot no. A-44, A Block, New Friends Colony, Delhi  Delhi       3899
# 107    Plot no. E-301, E Block, East of Kailash, Delhi  Delhi       3699
# 108                        B Block, Safdurjung Enclave  Delhi       3449
# ...

# %% [markdown]
# ## These all are already booked oyo hotels

# %%
df.iloc[np.where(df['PRICE AFTER DISCOUNT']==max(df['PRICE AFTER DISCOUNT']))]
# Out:
#                               HOTEL NAME         LOCALITY REGION  OLD PRICE  \
# 130  OYO Premium 208 GK 1 M Block Market  Greater Kailash  Delhi       6849
#
#      PRICE AFTER DISCOUNT % DISCOUNT     STATUS
# 130                  5137    25% OFF  SOLD OUT

# %% [markdown]
# ## This is the maximum price of oyo hotel at Greater Kailash

# %%
df.iloc[np.where(df['PRICE AFTER DISCOUNT']==min(df['PRICE AFTER DISCOUNT']))]
# Out:
#                                      HOTEL NAME       LOCALITY REGION  \
# 246  OYO Rooms 298 38 Arakashan Road Pahar Ganj  Arakshan Road  Delhi
#
#      OLD PRICE  PRICE AFTER DISCOUNT % DISCOUNT     STATUS
# 246        749                   562    25% OFF  SOLD OUT

# %% [markdown]
# ## This is the minimum price oyo hotel at pahar ganj

# %%
df['% DISCOUNT'].value_counts()
# Out:
# 25% OFF    330
# Name: % DISCOUNT, dtype: int64

# %% [markdown]
# ## All hotels are giving 25% discount

# %%
df['HOTEL NAME'].value_counts()
# Out:
# OYO Flagship 573 Paharganj NDLS              2
# OYO Premium 529 Jasola Vihar                 2
# OYO Rooms 641 Sector 7 Palam Extension       2
# OYO Apartments 273 Dwarka Sector 12          2
# OYO Flagship 551 Karol Bagh                  2
#                                             ..
# OYO Premium 534 Dwarka Near Ramphal Chowk    1
# OYO Rooms 179 Kashmere Gate                  1
# OYO Premium 582 Pitampura                    1
# OYO Premium 292 Lajpat Nagar Main Road       1
# OYO Rooms 498 South Ex Market                1
# Name: HOTEL NAME, Length: 321, dtype: int64

# %%
import scipy.stats as ss

# %%
from statsmodels.stats.weightstats import ztest

# %%
df['OLD PRICE'].mean()
# Out:
# 2594.5454545454545

# %%
q=df['OLD PRICE'][0:40]
q
# Out:
# 0     2649
# 1     3149
# 2     1799
# 3     1999
# 4     3899
# 5     1799
# 6     6099
# 7     1799
# 8     1664
# 9     4849
# 10    1699
# 11    1664
# 12    3699
# 13    3149
# 14    4299
# 15    3799
# 16    4649
# 17    2499
# 18    3749
# 19    3249
# 20    4749
# 21    3549
# 22    2499
# 23    3449
# 24    4799
# 25    2499
# 26    3499
# 27    4299
# 28    2899
# 29    2149
# 30    2199
# 31    1849
# 32    2549
# 33    2449
# 34    2049
# 35    2049
# 36    2499
# 37    1699
# 38    3099
# 39    1999
# Name: OLD PRICE, dtype: int32

# %%
q.mean()
# Out:
# 2974.75

# %%
q.std()
# Out:
# 1111.4892700498272

# %%
zval,pval = ztest(q,value=2594.54,alternative='smaller')
print(round(pval,2))
if pval<0.05:
    print("reject null hypothesis")
else:
    print("accept null hypothesis")
# Out:
# 0.98
# accept null hypothesis
